# %% [markdown]
# # FL Studio Tuturials on Youtube

# %% [markdown]
# ## Getting started

# %%
# Run this cell once, this will install the API client.
pip install google-api-python-client
# Out:
#   File "<ipython-input-17-74f9a5c52015>", line 2
#     pip install google-api-python-client
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Once installed, restart and clean the kernel and continue from here:

# %%
#kan weg
api_key = 'AIzaSyAuzxscfTqg5ElsuRhMHQx9zJGZyVzDqpM' #API code Sam
api_key = 'AIzaSyBiBM47drg5csNW-V-wOZjNN-Vl5rfHNPM' #API code Jeroen
api_key = 'AIzaSyB770EnyGnPvNtdIgvqVyZIsnBeinWuyzQ' #API code Quinten
api_key = 'AIzaSyA0v2in7KbrgrmjyxTBOrGcLEDn5QJeKio' #API code Tayfun

# %%
from googleapiclient.discovery import build
import csv
import time
import os
import json

# %%
api_key = os.environ["YOUTUBE_API"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-e2d9430a6e1c> in <module>
# ----> 1 api_key = os.environ["YOUTUBE_API"]
#
# /opt/anaconda3/lib/python3.8/os.py in __getitem__(self, key)
#     673         except KeyError:
#     674             # raise KeyError with the original key value
# --> 675             raise KeyError(key) from None
#     676         return self.decodevalue(value)
#     677
#
# KeyError: 'YOUTUBE_API'

# %%
youtube = build('youtube', 'v3', developerKey= api_key)
youtube

# %% [markdown]
# #### Testing the systems
# The cells below will check whether the API functions.

# %%
# check the default number of results, this should give 5
request = youtube.search().list(
            q='FL tutorial',
            part='snippet',
            type='video')
print(type(request))
response = request.execute()
print('Total items: ' , len(response['items']))
# Out:
# <class 'googleapiclient.http.HttpRequest'>
# Total items:  5

# %%
# use this to increase to max of 50
request = youtube.search().list(q='FL tutorial',part='snippet',type='video',maxResults=50)
print(type(request))
response = request.execute()
print('Total items: ' , len(response['items']))
# Out:
# <class 'googleapiclient.http.HttpRequest'>
# Total items:  50

# %% [markdown]
# If the two cells above gave you the outputs **5** and **50** respectfully, the API works correctly.

# %% [markdown]
# #### Gathering the data

# %%
# print only the titles of the results within the retrieval range of 50.
request = youtube.search().list(q='FL tutorial',part='snippet',type='video',maxResults=50)
response = request.execute()
next_page = response['nextPageToken']
print(next_page) # to get next page token
for item in response['items']:
    print(item['snippet']['title'])
# Out:
# CDIQAA
# FL Studio 20  -  Complete Beginner Basics Tutorial
# FL Studio 20 Tutorial | Full FL Studio Crash Course | FL Studio Beginners Guide to Music Production
# FL STUDIO 20 BEGINNER BEAT MAKING TUTORIAL 2020 (Part 1)
# FL STUDIO BEAT MAKING TUTORIAL FOR BEGINNERS 2021 | Secret Sauce - Episode 1
# How to Make a Song in FL Studio 20 💻 | Software Lesson
# FL Studio 20 - MasterClass - Complete Basics Tutorial - in Hindi
# FL Studio 20 - Tutorial for Beginners [COMPLETE] in 16 MINUTES!
# METRO BOOMIN | Beats Tutorial | FL Studio &amp; Razer Music
# 🍑 FL Studio 20 - #1: Primeros pasos [CURSO COMPLETO]
# How to Make Bouncy Trap Songs | FL Studio Tutorial
# FL Studio 20 für Anfänger #1 Tutorial auf Deutsch
# Como usar FL STUDIO 20? (Tutorial completo)
# How To Make Kawaii Future Bass - FL Studio 20 Tutorial
# Making an Afro Beat from Scratch | FL Studio Beginner Tutorial 2021
# COME USARE FL STUDIO PER FARE UN BEAT - Tutorial per Principianti ITA
# MAKING A DARK UK DRILL BEAT FOR HEADIE ONE (UK Drill Tutorial - FL Studio)
# HOW TO MAKE BEAUTIFUL SOUNDING MELODIES | How To Make Melodies | FL Studio 20 Tutorial
# How To Fisher Style Full Tech House Track - FL Studio 20 Tutorial [Presets and Project]
# TUTORIAL FL STUDIO 12 | LEZIONE 1: INTRODUZIONE, SEZIONI PRINCIPALI, INIZIARE UN PROGETTO (ITALIANO)
# How To Make Folk Music In FL Studio! (Tutorial)
# Turning Squid Game&#39;s OST Into 3 Different Genres - FL Studio 20 Tutorial (Pink Soldiers)
# How to Lofi Hip Hop | FL Studio Tutorial
# HOE MAAK JE EEN TRAP BEAT? | FL Studio Tutorial (2020)
# How to Use FL Studio 20 | Beginner Basic Tutorial
# HOW TO: Hardstyle like KELTEK - Fl Studio Tutorial
# FL Studio 20 - Tutorial Completo Básico para Iniciantes (EP. 1)
# This Hidden Drum Setting In FL Studio Will Change Your Drum Making Forever!🔥🤯 (Groove Tutorial)
# How To Use The Edison - FL Studio Tutorial
# HOW TO MAKE: Deep House - FL Studio tutorial
# HOE MAAK JE EEN DRILL BEAT! - FL Studio Tutorial [Nederlands]
# 🔥 2021 FL STUDIO Beginners Tutorial - Lesson 1 - Make A Beat 🔥
# HOE MAAK JE EEN JOSYLVIO TYPE BEAT IN 2021? | (FL Studio Tutorial)
# HOW TO: Hardstyle / Rawstyle like D-Sturb - Fl Studio Tutorial
# How To Vocode in FL Studio - Vocodex Tutorial
# How To Make Slap House - FL Studio 20 Tutorial
# FPC Tutorial - Everything You Need To Know - FL Studio 20 Basics
# Maximus Tutorial - What You Need to Know - FL Studio 20
# FL Studio 20 - Oδηγίες για αρχάριους (#1)  | Greek Tutorial |
# HARDSTYLE KICK MET STOCK PLUGINS!! - FL Studio Tutorial [Nederlands]
# 🎧COMO usar FL STUDIO 20  para PRINCIPIANTES (Crear tu primera canción) 🎧
# Tutorial Dasar Membuat Musik di FL Studio Untuk Pemula
# Como Usar o FL Studio, Tutorial Completo para Iniciantes / Curso de Produção Musical
# EASY &#39;BEGINNER&#39; TRICKS - FL Studio tutorial
# HOE MAAK JE EEN BOEF TYPE BEAT IN 2021? | (FL Studio Tutorial)
# HOW TO MAKE: Orchestral / Film score music - FL Studio tutorial + FLP
# FL STUDIO | Mixer Routing - Getting Started Tutorial
# Fl Studio | Alan Walker Fade/d Tutorial | + Free Presets!
# How To Make Bouncy Afrobeats (Wizkid, Tems, Rema) | FL Studio Tutorial
# HOW TO MAKE: EDM like KSHMR - FL Studio tutorial + FLP
# Hoe Maak Je Een Jack Type Beat ? | FL Studio Tutorial (2021)

# %%
# counts results within the retrieval range of 50 per page (page 0,1,2,3,4,5 etc).
# with every page the output provides iteration number and the nextPageToken
no_requests = 0
max_requests = 9

search_res = []

while no_requests <= max_requests:
    no_requests += 1
    print('iteration number:' + str(no_requests))
    if (no_requests==1): 
        request = youtube.search().list(q='FL tutorial',part='snippet',type='video',maxResults=50)
    else: 
        request = youtube.search().list(q='FL tutorial',part='snippet',type='video',maxResults=50, pageToken = next_page)
       
    response = request.execute()
    next_page = response['nextPageToken']
    print(next_page)

    for item in response['items']:
        search_res.append(item['snippet'])
    time.sleep(1) ###### change to 2

len(search_res)
# Out:
# iteration number:1
# CDIQAA
# iteration number:2
# CGQQAA
# iteration number:3
# CJYBEAA
# iteration number:4
# CMgBEAA
# iteration number:5
# CPoBEAA
# iteration number:6
# CKwCEAA
# iteration number:7
# CN4CEAA
# iteration number:8
# CJADEAA
# iteration number:9
# CMIDEAA
# iteration number:10
# CPQDEAA
# 500

# %%
### makes a list of videoIDs

videoIDs = []

for item in search_res:
    videoIDs.append(item['thumbnails']['default']['url'][23:34])

print("Found " + str(len(videoIDs)) + " video IDs!")
# Out:
# Found 0 video IDs!

# %%
# delete later, since it doesnt add anything. Only helps for visualization.
search_res[0:2] # only 2 to have some overview
# Out:
# []

# %%
# --- stats --- #
cnt=0
for vid in videoIDs:
    cnt+=1
    if (cnt==5): 
        break   # overview for only 5 results, just to give impression
    stats = youtube.videos().list(part='statistics',id=vid)
    print(stats.execute())

# %%
#### response for stats 
response_stats = []

for vid in videoIDs:
    stats = youtube.videos().list(part='statistics',id=vid)
    response_stats.append(stats.execute())
    res_stats = {}
    
    for item in response_stats:
        stats = item['items'][0]['statistics']
        res_stats[item['items'][0]['id']] = stats

res_stats
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-358e24d25b15> in <module>
#      11         res_stats[item['items'][0]['id']] = stats
#      12
# ---> 13 res_stats
#
# NameError: name 'res_stats' is not defined

# %%
# output stats to json file
import json
converted_to_string = json.dumps(res_stats)
f = open('stats_output.json', 'a', encoding='utf-8')
f.write(converted_to_string + '\n')
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-d46bff78a962> in <module>
#       1 # output stats to json file
#       2 import json
# ----> 3 converted_to_string = json.dumps(res_stats)
#       4 f = open('stats_output.json', 'a', encoding='utf-8')
#       5 f.write(converted_to_string + '\n')
#
# NameError: name 'res_stats' is not defined

# %%
# read json file for stats
f = open('stats_output.json', 'r', encoding='utf-8')
content = f.readlines()
for item in content:
    jsonobj = json.loads(item)
    print(jsonobj)
    f.close()
# Out:
# {'pDIsEZsalAo': {'viewCount': '7145552', 'likeCount': '199238', 'dislikeCount': '2184', 'favoriteCount': '0', 'commentCount': '6907'}, 'Lc4SHa-O4T0': {'viewCount': '1321060', 'likeCount': '62978', 'dislikeCount': '611', 'favoriteCount': '0', 'commentCount': '2448'}, 'x5-GweOYXtk': {'viewCount': '326490', 'likeCount': '7666', 'dislikeCount': '88', 'favoriteCount': '0', 'commentCount': '332'}, 'jYBjcEVTSB8': {'viewCount': '280360', 'likeCount': '14077', 'dislikeCount': '125', 'favoriteCount': '0', 'commentCount': '712'}, 'BdSnr_P4HzY': {'viewCount': '357694', 'likeCount': '15521', 'dislikeCount': '257', 'favoriteCount': '0', 'commentCount': '1461'}, '69Vpk3VKXBE': {'viewCount': '1475689', 'likeCount': '28362', 'dislikeCount': '993', 'favoriteCount': '0', 'commentCount': '887'}, 'EpxyGCVEpMs': {'viewCount': '2175658', 'likeCount': '80588', 'dislikeCount': '812', 'favoriteCount': '0', 'commentCount': '3919'}, 'Av4NhUWQ-24': {'viewCount': '1578744', 'likeCount': '33034', 'dislikeCount': '420', 'favoriteCount': '0'}, 'EzqIFVlRrMQ': {'viewCount': '676001', 'likeCount': '16672', 'dislikeCount': '248', 'favoriteCount': '0', 'commentCount': '848'}, '_SACMBFrZO4': {'viewCount': '843454', 'likeCount': '12141', 'dislikeCount': '403', 'favoriteCount': '0', 'commentCount': '535'}, 'E-XbdK1bGpc': {'viewCount': '17183', 'likeCount': '1106', 'dislikeCount': '8', 'favoriteCount': '0', 'commentCount': '98'}, 'xIU60H4BfeI': {'viewCount': '122639', 'likeCount': '10142', 'dislikeCount': '63', 'favoriteCount': '0', 'commentCount': '554'}, 'rv1Mz5NMlRQ': {'viewCount': '1691898', 'likeCount': '89944', 'dislikeCount': '1217', 'favoriteCount': '0', 'commentCount': '3163'}, 'E-sDui4fcsc': {'viewCount': '450884', 'likeCount': '13382', 'dislikeCount': '183', 'favoriteCount': '0', 'commentCount': '924'}, 'PNfsLB4THNk': {'viewCount': '66935', 'likeCount': '6355', 'dislikeCount': '37', 'favoriteCount': '0', 'commentCount': '199'}, 'es4DGH_fLL4': {'viewCount': '409506', 'likeCount': '10397', 'dislikeCount': '184', 'favoriteCount': '0', 'commentCount': '388'}, '2VXR8CajTbo': {'viewCount': '386665', 'likeCount': '12248', 'dislikeCount': '124', 'favoriteCount': '0', 'commentCount': '692'}, 'E3p0KGp2Leg': {'viewCount': '1572', 'likeCount': '63', 'dislikeCount': '3', 'favoriteCount': '0', 'commentCount': '34'}, '_4DxjDZnt2c': {'viewCount': '227153', 'likeCount': '8095', 'dislikeCount': '75', 'favoriteCount': '0', 'commentCount': '524'}, 'yiRlOeouS2k': {'viewCount': '726427', 'likeCount': '34193', 'dislikeCount': '342', 'favoriteCount': '0', 'commentCount': '1125'}, 'wX_7qdyKo_c': {'viewCount': '117363', 'likeCount': '6727', 'dislikeCount': '41', 'favoriteCount': '0', 'commentCount': '486'}, '6W79YK-LIa0': {'viewCount': '30519', 'likeCount': '1189', 'dislikeCount': '11', 'favoriteCount': '0', 'commentCount': '134'}, 'iuUc83K_w8U': {'viewCount': '6084', 'likeCount': '325', 'dislikeCount': '4', 'favoriteCount': '0', 'commentCount': '75'}, 'C8v-lPNwEwE': {'viewCount': '157727', 'likeCount': '6953', 'dislikeCount': '85', 'favoriteCount': '0', 'commentCount': '146'}, 'AeEGRj6DtSU': {'viewCount': '38129', 'likeCount': '1329', 'dislikeCount': '29', 'favoriteCount': '0', 'commentCount': '102'}, 'FjSIUi1P8d0': {'viewCount': '669762', 'likeCount': '14262', 'dislikeCount': '379', 'favoriteCount': '0', 'commentCount': '711'}, 'pqcwGikgWJQ': {'viewCount': '899957', 'likeCount': '26187', 'dislikeCount': '1365', 'favoriteCount': '0', 'commentCount': '1159'}, 'zl_jaJjG2sc': {'viewCount': '1500', 'likeCount': '64', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '26'}, '4ICwZjBvgpo': {'viewCount': '60538', 'likeCount': '2043', 'dislikeCount': '26', 'favoriteCount': '0'}, 'rGXi26QZqX8': {'viewCount': '13596', 'likeCount': '275', 'dislikeCount': '68', 'favoriteCount': '0', 'commentCount': '83'}, '7_ay-K_Xy80': {'viewCount': '9345', 'likeCount': '311', 'dislikeCount': '6', 'favoriteCount': '0', 'commentCount': '71'}, 'qYFoeH6gL-g': {'viewCount': '54423', 'likeCount': '1379',  ...

# %%
# read json df for stats

import pandas as pd
dfstats = pd.read_json(r'stats_output.json', orient = 'index')
dfstats
# Out:
#              viewCount  likeCount  dislikeCount  favoriteCount  commentCount
# pDIsEZsalAo    7145552   199238.0        2184.0              0        6907.0
# Lc4SHa-O4T0    1321060    62978.0         611.0              0        2448.0
# x5-GweOYXtk     326490     7666.0          88.0              0         332.0
# jYBjcEVTSB8     280360    14077.0         125.0              0         712.0
# BdSnr_P4HzY     357694    15521.0         257.0              0        1461.0
# ...                ...        ...           ...            ...           ...
# qmF_xo5YKN0     666332    11968.0         561.0              0         480.0
# g6mN3__pj1k        979       18.0           2.0              0           3.0
# xMx2rc4Zmcw        412       18.0           0.0              0           4.0
# 9n6vlwCmz8Y     101670      833.0          93.0              0         141.0
# 9FxQZmXchgU       2631       24.0           2.0              0           0.0
#
# [469 rows x 5 columns]

# %%
# write df for stats to csv
dfstats.to_csv('video_statistics.csv', index_label ='id')

# %% [markdown]
# End of stats

# %%
# --- snippets ---#
cnt=0
for vid in videoIDs:
    cnt+=1
    if (cnt==5): break
    snippets = youtube.videos().list(part='snippet',id=vid)
    print(snippets.execute())

# %%
#### response for snippets
response_snippets = []

for item in videoIDs:
    snippets = youtube.videos().list(part='snippet',id=item)
    response_snippets.append(snippets.execute())
    res_snippets = {}
    
    for item in response_snippets:
        snippets = item['items'][0]['snippet'] ### the script works per id
        res_snippets[item['items'][0]['id']] = snippets

res_snippets
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-307bb1e6e779> in <module>
#      11         res_snippets[item['items'][0]['id']] = snippets
#      12
# ---> 13 res_snippets
#
# NameError: name 'res_snippets' is not defined

# %%
# output snippets to json file
import json
converted_to_string = json.dumps(res_snippets)
f = open('snippet_output.json', 'a', encoding='utf-8')
f.write(converted_to_string + '\n')
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-f0b67297e6aa> in <module>
#       1 # output snippets to json file
#       2 import json
# ----> 3 converted_to_string = json.dumps(res_snippets)
#       4 f = open('snippet_output.json', 'a', encoding='utf-8')
#       5 f.write(converted_to_string + '\n')
#
# NameError: name 'res_snippets' is not defined

# %%
# read json file for snippet
f = open('snippet_output.json', 'r', encoding='utf-8')
content = f.readlines()
for item in content:
    jsonobj = json.loads(item)
    print(jsonobj)
    f.close()
# Out:
# {'pDIsEZsalAo': {'publishedAt': '2018-05-23T15:33:40Z', 'channelId': 'UCIcCXe3iWo6lq-iWKV40Oug', 'title': 'FL Studio 20  -  Complete Beginner Basics Tutorial', 'description': 'This video is the first in the FL Studio 20 Basics Playlist and is to help those who are completely new to FL Studio and are looking for a place to start. When loading a synth for the first time, I would recommend using "FLEX" it is the best and most easy to use and was added after I made this video. \n\nWatch the FL Studio 20 Basics Playlist here : https://goo.gl/2Yxrf2\n\nI try to simplify the DAW and it\'s signal flow for those who are not familiar with FL Studio\'s workflow.\n\nThis video shows how to navigate the Browser, Channel Rack, Playlist, Piano Roll and Mixer so that you can start making music :)\nThere are far too many features to cover in one video but luckily there are lots more (shorter) videos on each topic.\nFor more detailed videos on each topic - \n\nChannel Rack -                    https://youtu.be/od5lD20Mnvw\nPlaylist -                               https://youtu.be/TkTZLblecPM\nMixer-                                   https://youtu.be/f1wVqmhLxUc\nDrum Programming -         https://youtu.be/bSrR-6BCGy4\nRecording Audio -               https://youtu.be/f4tqN19EPlQ\nSide chaining -                    https://youtu.be/Zl-uG5oIUdg\nExport Settings -                 https://youtu.be/0rEnGUUJ5oA\nShortcuts -                           https://youtu.be/_SS6ZYlxZ7Q\nWorkflow Tips -                   https://youtu.be/aBzQ5KV4glE\nFree Templates -                 https://youtu.be/V5Lj6M1mdmI\n\nNote - Your FL Studio version might look a little different depending on your screen size and resolution. I also have the effects on the mixer default to the left hand side- yours might be on the right, this doesn\'t change the function :)\n\n🌍 My Website / Contact / Hire me - https://michaelwynneaudio.com\n\n📱 Join My Discord - https://discord.com/invite/inthemix\n\n🎧 My Sound Banks / Preset Packs - https://inthemix.store\n\n💸 Save money on DistroKid if you signup through my custom link - http://distrokid.com/vip/inthemix', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pDIsEZsalAo/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/pDIsEZsalAo/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/pDIsEZsalAo/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/pDIsEZsalAo/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/pDIsEZsalAo/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'In The Mix', 'tags': ['FL Studio 20', 'FL Studio 20 begginer tutorial', 'FL Studio 20 complete begginner', 'FL Studio 20 basics', 'fl studio 20 basics', 'beginner tutorial', 'how to use fl studio 20', 'fl 20', 'gettting started in FL Studi', 'FL Studio Beginner Tutorial', 'fl studio', 'fl studio tutorial'], 'categoryId': '26', 'liveBroadcastContent': 'none', 'localized': {'title': 'FL Studio 20  -  Complete Beginner Basics Tutorial', 'description': 'This video is the first in the FL Studio 20 Basics Playlist and is to help those who are completely new to FL Studio and are looking for a place to start. When loading a synth for the first time, I would recommend using "FLEX" it is the best and most easy to use and was added after I made this video. \n\nWatch the FL Studio 20 Basics Playlist here : https://goo.gl/2Yxrf2\n\nI try to simplify the DAW and it\'s signal flow for those who are not familiar with FL Studio\'s workflow.\n\nThis video shows how to navigate the Browser, Channel Rack, Playlist, Piano Roll and Mixer so that you can start making music :)\nThere are far too many features to cover in one video but luckily there are lots more (shorter) videos on each topic.\nFor more detailed videos on each topic - \n\nChannel Rack -                    https://youtu.be/od5lD20Mnvw\nPlaylist -                 ...

# %%
# read json df for snippet

import pandas as pd
dfsnip = pd.read_json(r'snippet_output.json', orient = 'index')
dfsnip
# Out:
#                       publishedAt                 channelId  \
# pDIsEZsalAo  2018-05-23T15:33:40Z  UCIcCXe3iWo6lq-iWKV40Oug
# Lc4SHa-O4T0  2020-05-28T18:00:09Z  UC4Oy0UtQpTBGX46q_OkWzXg
# x5-GweOYXtk  2020-01-29T09:18:58Z  UCIUtwq6jMFYQj2ASOj95TGw
# jYBjcEVTSB8  2020-12-25T16:21:45Z  UC4Oy0UtQpTBGX46q_OkWzXg
# BdSnr_P4HzY  2021-01-05T13:36:23Z  UC-_r3ybLeGdNfca0UriJ6XA
# ...                           ...                       ...
# qmF_xo5YKN0  2017-08-27T16:10:54Z  UCqPdU0C6sIx_kkEoAcW9hSQ
# g6mN3__pj1k  2017-05-25T06:18:29Z  UCDgDpexiTLvQA6dtjh7GGiw
# xMx2rc4Zmcw  2021-06-20T19:00:22Z  UCeiPYPFoCdu7pa30Cvf33Cg
# 9n6vlwCmz8Y  2014-01-10T14:02:38Z  UC0QnMkz74etr6MbUAq6Qy1w
# 9FxQZmXchgU  2016-05-01T10:12:42Z  UCyHsIoSb3Yb-N1_LbogOidg
#
#                                                          title  \
# pDIsEZsalAo  FL Studio 20  -  Complete Beginner Basics Tuto...
# Lc4SHa-O4T0  FL STUDIO 20 BEGINNER BEAT MAKING TUTORIAL 202...
# x5-GweOYXtk  FL Studio 20 Tutorial | Full FL Studio Crash C...
# jYBjcEVTSB8  FL STUDIO BEAT MAKING TUTORIAL FOR BEGINNERS 2...
# BdSnr_P4HzY  FL Studio 20 - MasterClass - Complete Basics T...
# ...                                                        ...
# qmF_xo5YKN0          HOW TO MAKE: Remixes - FL Studio tutorial
# g6mN3__pj1k                       FL STUDIO tutorial in ROMANA
# xMx2rc4Zmcw  How to make SCARY Circus Samples like Cubeatz ...
# 9n6vlwCmz8Y          FL Studio Big Room Tutorial #1 - FREE FLP
# 9FxQZmXchgU  Psytrance tutorial in FL studio for.. HATS/SNA...
#
#                                                    description  \
# pDIsEZsalAo  This video is the first in the FL Studio 20 Ba...
# Lc4SHa-O4T0  FL STUDIO 20 BEGINNER BEAT MAKING TUTORIAL 202...
# x5-GweOYXtk  ✅Click Below to get our full Complete FL Studi...
# jYBjcEVTSB8  'Secret Sauce' , Episode 1 - How to make beats...
# BdSnr_P4HzY  Support The Channel 💰 - https://www.instamojo....
# ...                                                        ...
# qmF_xo5YKN0  ▼ In this tutorial I will show you how you can...
# g6mN3__pj1k                       FL STUDIO tutorial in ROMANA
# xMx2rc4Zmcw  how to make scary circus samples\nCopyright © ...
# 9n6vlwCmz8Y  Watch the Second New Tutorial Here! : https://...
# 9FxQZmXchgU  Thanks for watching and below are the links to...
#
#                                                     thumbnails  \
# pDIsEZsalAo  {'default': {'url': 'https://i.ytimg.com/vi/pD...
# Lc4SHa-O4T0  {'default': {'url': 'https://i.ytimg.com/vi/Lc...
# x5-GweOYXtk  {'default': {'url': 'https://i.ytimg.com/vi/x5...
# jYBjcEVTSB8  {'default': {'url': 'https://i.ytimg.com/vi/jY...
# BdSnr_P4HzY  {'default': {'url': 'https://i.ytimg.com/vi/Bd...
# ...                                                        ...
# qmF_xo5YKN0  {'default': {'url': 'https://i.ytimg.com/vi/qm...
# g6mN3__pj1k  {'default': {'url': 'https://i.ytimg.com/vi/g6...
# xMx2rc4Zmcw  {'default': {'url': 'https://i.ytimg.com/vi/xM...
# 9n6vlwCmz8Y  {'default': {'url': 'https://i.ytimg.com/vi/9n...
# 9FxQZmXchgU  {'default': {'url': 'https://i.ytimg.com/vi/9F...
#
#                     channelTitle  \
# pDIsEZsalAo           In The Mix
# Lc4SHa-O4T0       Chuki Beats II
# x5-GweOYXtk         Tomas George
# jYBjcEVTSB8       Chuki Beats II
# BdSnr_P4HzY       Dev Next Level
# ...                          ...
# qmF_xo5YKN0  The Producer School
# g6mN3__pj1k             My Music
# xMx2rc4Zmcw            thompshon
# 9n6vlwCmz8Y                Silas
# 9FxQZmXchgU               Yobott
#
#                                                           tags  categoryId  \
# pDIsEZsalAo  [FL Studio 20, FL Studio 20 begginer tutorial,...          26
# Lc4SHa-O4T0  [making a beat in fl studio, making a beat, ma...          26
# x5-GweOYXtk                                                NaN          27
# jYBjcEVTSB8  [making a beat in fl studio, making a beat, ma...          26
# BdSnr_P4HzY  [fl studio tutorial, fl studio tutorial in hin...          10
# ...                                                        ...         ...
# qmF_xo5YKN0  [FL Studio, music, remix, tutorial, help, EDM,...          10
# g6mN3__pj1k                     [FL STUDIO tutorial in ROMANA]          26
# xMx2rc4Zmcw  [fl studio tutorial, thompshon, fl studio, cub...          10
# 9n6vlwCmz8Y  [music, mix, eternity, electro, drop, tutorial...          10
# 9FxQZmXchgU    [Psytrance, Psychedelic, Trance, EDM, Tutorial]          10
#
#             liveBroadcastContent  \
# pDIsEZsalAo                 none
# Lc4SHa-O4T0                 none
# x5-GweOYXtk                 none
# jYBjcEVTSB8                 none
# BdSnr_P4HzY                 none
# ...                          ...
# qmF_xo5YKN0                 none
# g6mN3__pj1k                 none
# xMx2rc4Zmcw                 none
# 9n6vlwCmz8Y                 none
# 9FxQZmXchgU                 none
#
#                                                      localized  \
# pDIsEZsalAo  {'title': 'FL Studio 20  -  Complete Beginner ...
# Lc4SHa-O4T0  {'title': 'FL STUDIO 20 BEGINNER BEAT MAKING T...
# x5-GweOYXtk  {'title': 'FL Studio 20 Tutorial | Full FL Stu...
# jYBjcEVTSB8  {'title': 'FL STUDIO BEAT MAKING TUTORIAL FOR ...
# BdSnr_P4HzY  {'title': 'FL Studio 20 - MasterClass - Comple...
# ...                                                        ...
# qmF_xo5YKN0  {'title': 'HOW TO MAKE: Remixes - FL Studio tu...
# g6mN3__pj1k  {'title': 'FL STUDIO tutorial in ROMANA', 'des...
# xMx2rc4Zmcw  {'title': 'How to make SCARY Circus Samples li...
# 9n6vlwCmz8Y  {'title': 'FL Studio Big Room Tutorial #1 - FR...
# 9FxQZmXchgU  {'title': 'Psytrance tutorial in FL studio for...
#
#             defaultAudioLanguage defaultLanguage
# pDIsEZsalAo                en-GB             NaN
# Lc4SHa-O4T0                   en              en
# x5-GweOYXtk                en-GB             NaN
# jYBjcEVTSB8                   en              en
# BdSnr_P4HzY                  NaN             NaN
# ...                          ...             ...
# qmF_xo5YKN0                  NaN             NaN
# g6mN3__pj1k                  NaN             NaN
# xMx2rc4Zmcw                  NaN             NaN
# 9n6vlwCmz8Y                  NaN             NaN
# 9FxQZmXchgU                  NaN             NaN
#
# [469 rows x 12 columns]

# %%
# write df for snippet to csv
dfsnip.to_csv('video_snippets.csv', index_label ='id')

# %%
#--- merging --- #
dfsnip = pd.read_csv('video_snippets.csv')
dfstats = pd.read_csv('video_statistics.csv')

dfmerged = dfsnip.merge(dfstats, on='id')
dfmerged
# Out:
#               id           publishedAt                 channelId  \
# 0    pDIsEZsalAo  2018-05-23T15:33:40Z  UCIcCXe3iWo6lq-iWKV40Oug
# 1    Lc4SHa-O4T0  2020-05-28T18:00:09Z  UC4Oy0UtQpTBGX46q_OkWzXg
# 2    x5-GweOYXtk  2020-01-29T09:18:58Z  UCIUtwq6jMFYQj2ASOj95TGw
# 3    jYBjcEVTSB8  2020-12-25T16:21:45Z  UC4Oy0UtQpTBGX46q_OkWzXg
# 4    BdSnr_P4HzY  2021-01-05T13:36:23Z  UC-_r3ybLeGdNfca0UriJ6XA
# ..           ...                   ...                       ...
# 464  qmF_xo5YKN0  2017-08-27T16:10:54Z  UCqPdU0C6sIx_kkEoAcW9hSQ
# 465  g6mN3__pj1k  2017-05-25T06:18:29Z  UCDgDpexiTLvQA6dtjh7GGiw
# 466  xMx2rc4Zmcw  2021-06-20T19:00:22Z  UCeiPYPFoCdu7pa30Cvf33Cg
# 467  9n6vlwCmz8Y  2014-01-10T14:02:38Z  UC0QnMkz74etr6MbUAq6Qy1w
# 468  9FxQZmXchgU  2016-05-01T10:12:42Z  UCyHsIoSb3Yb-N1_LbogOidg
#
#                                                  title  \
# 0    FL Studio 20  -  Complete Beginner Basics Tuto...
# 1    FL STUDIO 20 BEGINNER BEAT MAKING TUTORIAL 202...
# 2    FL Studio 20 Tutorial | Full FL Studio Crash C...
# 3    FL STUDIO BEAT MAKING TUTORIAL FOR BEGINNERS 2...
# 4    FL Studio 20 - MasterClass - Complete Basics T...
# ..                                                 ...
# 464          HOW TO MAKE: Remixes - FL Studio tutorial
# 465                       FL STUDIO tutorial in ROMANA
# 466  How to make SCARY Circus Samples like Cubeatz ...
# 467          FL Studio Big Room Tutorial #1 - FREE FLP
# 468  Psytrance tutorial in FL studio for.. HATS/SNA...
#
#                                            description  \
# 0    This video is the first in the FL Studio 20 Ba...
# 1    FL STUDIO 20 BEGINNER BEAT MAKING TUTORIAL 202...
# 2    ✅Click Below to get our full Complete FL Studi...
# 3    'Secret Sauce' , Episode 1 - How to make beats...
# 4    Support The Channel 💰 - https://www.instamojo....
# ..                                                 ...
# 464  ▼ In this tutorial I will show you how you can...
# 465                       FL STUDIO tutorial in ROMANA
# 466  how to make scary circus samples\nCopyright © ...
# 467  Watch the Second New Tutorial Here! : https://...
# 468  Thanks for watching and below are the links to...
#
#                                             thumbnails         channelTitle  \
# 0    {'default': {'url': 'https://i.ytimg.com/vi/pD...           In The Mix
# 1    {'default': {'url': 'https://i.ytimg.com/vi/Lc...       Chuki Beats II
# 2    {'default': {'url': 'https://i.ytimg.com/vi/x5...         Tomas George
# 3    {'default': {'url': 'https://i.ytimg.com/vi/jY...       Chuki Beats II
# 4    {'default': {'url': 'https://i.ytimg.com/vi/Bd...       Dev Next Level
# ..                                                 ...                  ...
# 464  {'default': {'url': 'https://i.ytimg.com/vi/qm...  The Producer School
# 465  {'default': {'url': 'https://i.ytimg.com/vi/g6...             My Music
# 466  {'default': {'url': 'https://i.ytimg.com/vi/xM...            thompshon
# 467  {'default': {'url': 'https://i.ytimg.com/vi/9n...                Silas
# 468  {'default': {'url': 'https://i.ytimg.com/vi/9F...               Yobott
#
#                                                   tags  categoryId  \
# 0    ['FL Studio 20', 'FL Studio 20 begginer tutori...          26
# 1    ['making a beat in fl studio', 'making a beat'...          26
# 2                                                  NaN          27
# 3    ['making a beat in fl studio', 'making a beat'...          26
# 4    ['fl studio tutorial', 'fl studio tutorial in ...          10
# ..                                                 ...         ...
# 464  ['FL Studio', 'music', 'remix', 'tutorial', 'h...          10
# 465                   ['FL STUDIO tutorial in ROMANA']          26
# 466  ['fl studio tutorial', 'thompshon', 'fl studio...          10
# 467  ['music', 'mix', 'eternity', 'electro', 'drop'...          10
# 468  ['Psytrance', 'Psychedelic', 'Trance', 'EDM', ...          10
#
#     liveBroadcastContent                                          localized  \
# 0                   none  {'title': 'FL Studio 20  -  Complete Beginner ...
# 1                   none  {'title': 'FL STUDIO 20 BEGINNER BEAT MAKING T...
# 2                   none  {'title': 'FL Studio 20 Tutorial | Full FL Stu...
# 3                   none  {'title': 'FL STUDIO BEAT MAKING TUTORIAL FOR ...
# 4                   none  {'title': 'FL Studio 20 - MasterClass - Comple...
# ..                   ...                                                ...
# 464                 none  {'title': 'HOW TO MAKE: Remixes - FL Studio tu...
# 465                 none  {'title': 'FL STUDIO tutorial in ROMANA', 'des...
# 466                 none  {'title': 'How to make SCARY Circus Samples li...
# 467                 none  {'title': 'FL Studio Big Room Tutorial #1 - FR...
# 468                 none  {'title': 'Psytrance tutorial in FL studio for...
#
#     defaultAudioLanguage defaultLanguage  viewCount  likeCount  dislikeCount  \
# 0                  en-GB             NaN    7145552   199238.0        2184.0
# 1                     en              en    1321060    62978.0         611.0
# 2                  en-GB             NaN     326490     7666.0          88.0
# 3                     en              en     280360    14077.0         125.0
# 4                    NaN             NaN     357694    15521.0         257.0
# ..                   ...             ...        ...        ...           ...
# 464                  NaN             NaN     666332    11968.0         561.0
# 465                  NaN             NaN        979       18.0           2.0
# 466                  NaN             NaN        412       18.0           0.0
# 467                  NaN             NaN     101670      833.0          93.0
# 468                  NaN             NaN       2631       24.0           2.0
#
#      favoriteCount  commentCount
# 0                0        6907.0
# 1                0        2448.0
# 2                0         332.0
# 3                0         712.0
# 4                0        1461.0
# ..             ...           ...
# 464              0         480.0
# 465              0           3.0
# 466              0           4.0
# 467              0         141.0
# 468              0           0.0
#
# [469 rows x 18 columns]

# %%
dfmerged.to_csv('video_output.csv')

# %% [markdown]
# THE END

# %%
##### dit loop'en op channel ids
channel = youtube.channels().list(part='statistics',id='item')
channel.execute()
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'RuuXzTIr0OoDqI4S0RU6n4FqKEM',
#  'pageInfo': {'totalResults': 0, 'resultsPerPage': 5}}

# %%
########################################################################################################
            #------------------ back up codes   ------------------------#

### writer to csv    - old csv writer

import csv
    
with open("output.csv", "w") as csv_file:
    field_names = ["id"]
    print(field_names)
    # Get keys of dictonary for column naming 
    # next(iter()) gets first entry of dict
    for key in res_stats[next(iter(res_stats))].keys():
        field_names.append(key)
    print(field_names)
    
    writer = csv.writer(csv_file, delimiter = ";")
    writer.writerow(field_names)
    # Loop over the result dictionaries corresponding to the videoIDs we have retreived earlier
    for videoID in res_stats:
        row_content = [videoID]
        # Put each value from the current dict entry in the row_content
        [row_content.append(value) for value in list(res_stats[videoID].values())]
        writer.writerow(row_content)
    print('Printing completed!')
# Out:
# ['id']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-d3a094243670> in <module>
#      11     # Get keys of dictonary for column naming
#      12     # next(iter()) gets first entry of dict
# ---> 13     for key in res_stats[next(iter(res_stats))].keys():
#      14         field_names.append(key)
#      15     print(field_names)
#
# NameError: name 'res_stats' is not defined
