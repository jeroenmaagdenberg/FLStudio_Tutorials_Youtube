# %%
pd.read_json("outputfile.json",lines=True)
# Out:
#                                          pDIsEZsalAo  \
# 0  {'viewCount': '7124311', 'likeCount': '198533'...
# 1  {'viewCount': '7134689', 'likeCount': '198873'...
# 2  {'viewCount': '7134708', 'likeCount': '198873'...
# 3  {'viewCount': '7134708', 'likeCount': '198873'...
# 4  {'viewCount': '7134708', 'likeCount': '198873'...
# 5  {'viewCount': '7134708', 'likeCount': '198873'...
# 6  {'viewCount': '7134708', 'likeCount': '198873'...
# 7  {'viewCount': '7134708', 'likeCount': '198873'...
#
#                                          jYBjcEVTSB8  \
# 0  {'viewCount': '278023', 'likeCount': '13985', ...
# 1  {'viewCount': '279161', 'likeCount': '14024', ...
# 2  {'viewCount': '279161', 'likeCount': '14024', ...
# 3  {'viewCount': '279161', 'likeCount': '14024', ...
# 4  {'viewCount': '279161', 'likeCount': '14024', ...
# 5  {'viewCount': '279161', 'likeCount': '14024', ...
# 6  {'viewCount': '279161', 'likeCount': '14024', ...
# 7  {'viewCount': '279161', 'likeCount': '14024', ...
#
# ...
